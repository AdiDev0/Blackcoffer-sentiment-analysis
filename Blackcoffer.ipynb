# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import syllables
import warnings
warnings.filterwarnings('ignore')

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\adity\\OneDrive\\Desktop\\analysis'

# %% [markdown]
# ## Process the data from Input.csv

# %%
df = pd.read_excel("Input.xlsx")
df.head()
# Out:
#    URL_ID                                                URL
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...

# %%
df.URL[0]
# Out:
# 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/'

# %%
df.URL_ID.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# # Fetch the stop words from stop_word.txt and store them into a set

# %%
stop_words = set()

stop_word_dir = '.\\stop_words'

for filename in os.listdir(stop_word_dir):
    file_path = os.path.join(stop_word_dir, filename)
    if os.path.isfile(file_path) and filename.endswith('.txt'):
        with open(file_path, 'r') as f:
            words = f.read().split()
            print(words)
            lowercase_words = []
            for word in words:
                lowercase_words.append(word.casefold())
            stop_words.update(lowercase_words)

print(stop_words)
# Out:
# ['ERNST', 'YOUNG', 'DELOITTE', 'TOUCHE', 'KPMG', 'PRICEWATERHOUSECOOPERS', 'PRICEWATERHOUSE', 'COOPERS']
# ['AFGHANI', '|', 'Afghanistan', 'ARIARY', '|', 'Madagascar', 'BAHT', '|', 'Thailand', 'BALBOA', '|', 'Panama', 'BIRR', '|', 'Ethiopia', 'BOLIVAR', '|', 'Venezuela', 'BOLIVIANO', '|', 'Bolivia', 'CEDI', '|', 'Ghana', 'COLON', '|', 'Costa', 'Rica', 'CÓRDOBA', '|', 'Nicaragua', 'DALASI', '|', 'Gambia', 'DENAR', '|', 'Macedonia', '(Former', 'Yug.', 'Rep.)', 'DINAR', '|', 'Algeria', 'DIRHAM', '|', 'Morocco', 'DOBRA', '|', 'São', 'Tom', 'and', 'Príncipe', 'DONG', '|', 'Vietnam', 'DRAM', '|', 'Armenia', 'ESCUDO', '|', 'Cape', 'Verde', 'EURO', '|', 'Belgium', 'FLORIN', '|', 'Aruba', 'FORINT', '|', 'Hungary', 'GOURDE', '|', 'Haiti', 'GUARANI', '|', 'Paraguay', 'GULDEN', '|', 'Netherlands', 'Antilles', 'HRYVNIA', '|', 'Ukraine', 'KINA', '|', 'Papua', 'New', 'Guinea', 'KIP', '|', 'Laos', 'KONVERTIBILNA', 'MARKA', '|', 'Bosnia-Herzegovina', 'KORUNA', '|', 'Czech', 'Republic', 'KRONA', '|', 'Sweden', 'KRONE', '|', 'Denmark', 'KROON', '|', 'Estonia', 'KUNA', '|', 'Croatia', 'KWACHA', '|', 'Zambia', 'KWANZA', '|', 'Angola', 'KYAT', '|', 'Myanmar', 'LARI', '|', 'Georgia', 'LATS', '|', 'Latvia', 'LEK', '|', 'Albania', 'LEMPIRA', '|', 'Honduras', 'LEONE', '|', 'Sierra', 'Leone', 'LEU', '|', 'Romania', 'LEV', '|', 'Bulgaria', 'LILANGENI', '|', 'Swaziland', 'LIRA', '|', 'Lebanon', 'LITAS', '|', 'Lithuania', 'LOTI', '|', 'Lesotho', 'MANAT', '|', 'Azerbaijan', 'METICAL', '|', 'Mozambique', 'NAIRA', '|', 'Nigeria', 'NAKFA', '|', 'Eritrea', '
# %% [markdown]
# ## Count of vowels in a word

# %%
def count_syllables(word):
    return syllables.estimate(word)

# %% [markdown]
# ## Make a dict of all the pos and neg words and assign scores to them

# %%
with open('positive-words.txt', 'r') as f:
    pos_words = f.read().split()
with open('negative-words.txt', 'r') as f:
    neg_words = f.read().split()
    
custom_lexicon = {}

pos_words = [word for word in pos_words if word.casefold() not in stop_words]
neg_words = [word for word in neg_words if word.casefold() not in stop_words]

for word in pos_words:
    custom_lexicon[word] = 1
    
for word in neg_words:
    custom_lexicon[word] = -1

# %% [markdown]
# ## Sentiment Analysis and result calculations

# %%
def get_results(word_tokens, no_of_words, no_of_sentence, filtered_word_tokens, no_of_filtered_words, no_of_filtered_sentence, complex_words):
    sia = SentimentIntensityAnalyzer()
    sia.lexicon.update(custom_lexicon)

    pos_score = 0
    neg_score = 0

    for word in filtered_word_tokens:
        sentiment_scores = sia.polarity_scores(word)
        pos_score += sentiment_scores['pos']
        neg_score += sentiment_scores['neg']

    polarity_score = (pos_score-neg_score)/ ((pos_score + neg_score) + 0.000001)

    subjectivity_score = (pos_score + neg_score)/ ((no_of_filtered_words) + 0.000001)

    average_sentence_length = no_of_words/no_of_sentence

    percentage_of_complex_words = len(complex_words)/no_of_words

    fog_index = 0.4 * (average_sentence_length + percentage_of_complex_words)

    average_no_of_words_per_sentence = no_of_words/no_of_sentence
    
    syllable_count = sum([count_syllables(word) for word in word_tokens])
        
    syllable_count_per_word = syllable_count/no_of_words
    
    total_chars = sum([len(word) for word in word_tokens])
    
    avg_word_len = total_chars/no_of_words
    
    personal_pronouns = ['I', 'we', 'my', 'mine', 'our', 'ours', 'us']
    
    count_pronoun = 0
    
    for word in word_tokens:
        if word!='US' and word.lower() in personal_pronouns:
            count_pronoun+=1
    
    return pos_score, neg_score, polarity_score, subjectivity_score, average_sentence_length, percentage_of_complex_words, fog_index, average_no_of_words_per_sentence, len(complex_words), no_of_filtered_words, syllable_count_per_word, avg_word_len, count_pronoun

# %%
final_results = pd.DataFrame(columns = ['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE', 'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH', 'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX', 'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT','SYLLABLE COUNT PER WORD', 'AVG WORD LEN', 'PRONOUN COUNT'])

# %% [markdown]
# ## Print results

# %%
def print_results(URL_ID, URL, pos_score, neg_score, polarity_score, subjectivity_score, average_sentence_length, percentage_of_complex_words, fog_index, average_no_of_words_per_sentence, complex_words_count, no_of_filtered_words, syllable_count_per_word, avg_word_len, count_pronoun):
    print("URL_ID: ", URL_ID)
    print("URL: ", URL)
    print("pos_score: ", pos_score)
    print("neg_score: ", neg_score)
    print("polarity_score: ", polarity_score)
    print("subjectivity_score: ", subjectivity_score)
    print("average_sentence_length: ", average_sentence_length)
    print("percentage_of_complex_words: ", percentage_of_complex_words)
    print("fog_index: ", fog_index)
    print("average_no_of_words_per_sentence: ", average_no_of_words_per_sentence)
    print("complex_words_count: ", complex_words_count)
    print("subjectivity_score: ", subjectivity_score)
    print("word_count: ", no_of_filtered_words)
    print("avg_word_len: ", avg_word_len)
    print("count_pronoun: ", count_pronoun)
    print()

# %% [markdown]
# ## convert textual data into word tokens

# %%
def tokenize(text, URL_ID, URL):
    global final_results
    word_tokens = word_tokenize(text)
    sentence_tokens = sent_tokenize(text)

    no_of_words = len(word_tokens)
    no_of_sentence = len(sentence_tokens)

    filtered_word_tokens = [word for word in word_tokens if not word.lower() in stop_words]
    filtered_sent_tokens = [word for word in sentence_tokens if not word.lower() in stop_words]

    complex_words = [word for word in word_tokens if count_syllables(word) >= 3]

    no_of_filtered_words = len(filtered_word_tokens)
    no_of_filtered_sentence = len(filtered_sent_tokens)

    ps, ns, pos, ss, asl, pocw, fi, aws, cwc, wc, scpw, awl, cp = get_results(word_tokens, no_of_words, no_of_sentence, filtered_word_tokens, no_of_filtered_words, no_of_filtered_sentence, complex_words)
    
    print_results(URL_ID, URL, ps, ns, pos, ss, asl, pocw, fi, aws, cwc, wc, scpw, awl, cp)

    final_results = final_results.append({'URL_ID': URL_ID, 'URL': URL, 'POSITIVE SCORE' : ps, 'NEGATIVE SCORE': ns, 'POLARITY SCORE': pos, 'SUBJECTIVITY SCORE' : ss, 'AVG SENTENCE LENGTH': asl, 'PERCENTAGE OF COMPLEX WORDS': pocw, 'FOG INDEX': fi, 'AVG NUMBER OF WORDS PER SENTENCE': aws, 'COMPLEX WORD COUNT': cwc, 'WORD COUNT': wc, 'SYLLABLE COUNT PER WORD': scpw, 'AVG WORD LEN': awl, 'PRONOUN COUNT': cp} , ignore_index=True)

# %% [markdown]
# ## Data Scraping using BeautifulSoup

# %%
path = '.\\text_data\\'

for index, row in df.iterrows():
    id = row['URL_ID']
    filename = str(id) + '.txt'
    url = row['URL']
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h1', class_='entry-title').get_text()
        paragraphs = soup.find_all('p')

        with open(path + filename, mode='w', encoding='utf-8') as f:
            f.write(title + '\n')
            for p in paragraphs:
                f.write(p.get_text() + '\n')
        
        f.close()
        with open(path + filename, mode='r', encoding='utf-8') as f:
            text = f.read()
            tokenize(text, id, url)
    except requests.exceptions.RequestException as e:
        pass
# Out:
# URL_ID:  37
# URL:  https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# pos_score:  102.0
# neg_score:  40.0
# polarity_score:  0.4366197152350724
# subjectivity_score:  0.12251941318160532
# average_sentence_length:  26.64
# percentage_of_complex_words:  0.26176176176176175
# fog_index:  10.760704704704706
# average_no_of_words_per_sentence:  26.64
# complex_words_count:  523
# subjectivity_score:  0.12251941318160532
# word_count:  1159
# avg_word_len:  5.163163163163163
# count_pronoun:  4
#
# URL_ID:  38
# URL:  https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/
# pos_score:  95.0
# neg_score:  49.0
# polarity_score:  0.31944444222608026
# subjectivity_score:  0.18922470408774678
# average_sentence_length:  20.4875
# percentage_of_complex_words:  0.16473459426479561
# fog_index:  8.26089383770592
# average_no_of_words_per_sentence:  20.4875
# complex_words_count:  270
# subjectivity_score:  0.18922470408774678
# word_count:  761
# avg_word_len:  4.293471629042099
# count_pronoun:  8
#
# URL_ID:  39
# URL:  https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/
# pos_score:  91.0
# neg_score:  46.0
# polarity_score:  0.3284671508871011
# subjectivity_score:  0.13564356422213508
# average_sentence_length:  22.470588235294116
# percentage_of_complex_words:  0.2518324607329843
# fog_index:  9.08896827841084
# average_no_of_words_per_sentence:  22.470588235294116
# complex_words_count:  481
# subjectivity_score:  0.13564356422213508
# word_count:  1010
# avg_word_len:  4.896335078534031
# count_pronoun:  3
#
# URL_ID:  40
# URL:  https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/
# pos_score:  90.0
# neg_score:  35.0
# polarity_score:  0.43999999648000004
# subjectivity_score:  0.16087516066811433
# average_sentence_length:  19.293478260869566
# percentage_of_complex_words:  0.17295774647887324
# fog_index:  7.786574402939376
# average_no_of_words_per_sentence:  19.293478260869566
# complex_words_count:  307
# subjectivity_score:  0.16087516066811433
# word_count:  777
# avg_word_len:  4.420281690140845
# count_pronoun:  22
#
# URL_ID:  41
# URL:  https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/
# pos_score:  89.0
# neg_score:  31.0
# polarity_score:  0.4833333293055556
# subjectivity_score:  0.12565445013020476
# average_sentence_length:  25.103896103896105
# percentage_of_complex_words:  0.19399896533885153
# fog_index:  10.119158027693985
# average_no_of_words_per_sentence:  25.103896103896105
# complex_words_count:  375
# subjectivity_score:  0.12565445013020476
# word_count:  955
# avg_word_len:  4.578375581996896
# count_pronoun:  20
#
# URL_ID:  42
# URL:  https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/
# pos_score:  71.0
# neg_score:  26.0
# polarity_score:  0.463917520990541
# subjectivity_score:  0.1409883718880983
# average_sentence_length:  25.392857142857142
# percentage_of_complex_words:  0.180028129395218
# fog_index:  10.229154108900945
# average_no_of_words_per_sentence:  25.392857142857142
# complex_words_count:  256
# subjectivity_score:  0.1409883718880983
# word_count:  688
# avg_word_len:  4.467651195499297
# count_pronoun:  30
#
# URL_ID:  43
# URL:  https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/
# pos_score:  34.0
# neg_score:  13.0
# polarity_score:  0.44680850113173404
# subjectivity_score:  0.10955710930173168
# average_sentence_length:  18.666666666666668
# percentage_of_complex_words:  0.21428571428571427
# fog_index:  7.552380952380954
# average_no_of_words_per_sentence:  18.666666666666668
# complex_words_count:  180
# subjectivity_score:  0.10955710930173168
# word_count:  429
# avg_word_len:  4.553571428571429
# count_pronoun:  11
#
# URL_ID:  45
# URL:  https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/
# pos_score:  40.0
# neg_score:  15.0
# polarity_score:  0.4545454462809919
# subjectivity_score:  0.14473684172437673
# average_sentence_length:  22.166666666666668
# percentage_of_complex_words:  0.16917293233082706
# fog_index:  8.934335839599
# average_no_of_words_per_sentence:  22.166666666666668
# complex_words_count:  135
# subjectivity_score:  0.14473684172437673
# word_count:  380
# avg_word_len:  4.363408521303258
# count_pronoun:  2
#
# URL_ID:  46
# URL:  https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/
# pos_score:  101.0
# neg_score:  38.0
# polarity_score:  0.4532374068112417
# subjectivity_score:  0.12150349639728714
# average_sentence_length:  29.790123456790123
# percentage_of_complex_words:  0.20389556568586822
# fog_index:  11.997607608990398
# average_no_of_words_per_sentence:  29.790123456790123
# complex_words_count:  492
# subjectivity_score:  0.12150349639728714
# word_count:  1144
# avg_word_len:  4.508081226688769
# count_pronoun:  8
#
# URL_ID:  47
# URL:  https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/
# pos_score:  81.0
# neg_score:  74.0
# polarity_score:  0.04516129003121749
# subjectivity_score:  0.12831125817192776
# average_sentence_length:  24.52747252747253
# percentage_of_complex_words:  0.2025089605734767
# fog_index:  9.891992595218404
# average_no_of_words_per_sentence:  24.52747252747253
# complex_words_count:  452
# subjectivity_score:  0.12831125817192776
# word_count:  1208
# avg_word_len:  4.404121863799283
# count_pronoun:  0
#
# URL_ID:  48
# URL:  https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/
# pos_score:  55.0
# neg_score:  24.0
# polarity_score:  0.3924050583239866
# subjectivity_score:  0.11617647041738755
# average_sentence_length:  22.448275862068964
# percentage_of_complex_words:  0.2565284178187404
# fog_index:  9.081921711955081
# average_no_of_words_per_sentence:  22.448275862068964
# complex_words_count:  334
# subjectivity_score:  0.11617647041738755
# word_count:  680
# avg_word_len:  5.025345622119816
# count_pronoun:  11
#
# URL_ID:  49
# URL:  https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/
# pos_score:  56.0
# neg_score:  33.0
# polarity_score:  0.2584269633884611
# subjectivity_score:  0.11994609148255243
# average_sentence_length:  17.382716049382715
# percentage_of_complex_words:  0.19744318181818182
# fog_index:  7.03206369248036
# average_no_of_words_per_sentence:  17.382716049382715
# complex_words_count:  278
# subjectivity_score:  0.11994609148255243
# word_count:  742
# avg_word_len:  4.458096590909091
# count_pronoun:  6
#
# URL_ID:  50
# URL:  https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/
# pos_score:  86.0
# neg_score:  27.0
# polarity_score:  0.5221238891847444
# subjectivity_score:  0.15046604507261513
# average_sentence_length:  29.40983606557377
# percentage_of_complex_words:  0.18394648829431437
# fog_index:  11.837513021547235
# average_no_of_words_per_sentence:  29.40983606557377
# complex_words_count:  330
# subjectivity_score:  0.15046604507261513
# word_count:  751
# avg_word_len:  4.5089186176142695
# count_pronoun:  30
#
# URL_ID:  51
# URL:  https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/
# pos_score:  95.0
# neg_score:  23.0
# polarity_score:  0.6101694863544959
# subjectivity_score:  0.13470319619326118
# average_sentence_length:  22.025
# percentage_of_complex_words:  0.20204313280363223
# fog_index:  8.890817253121453
# average_no_of_words_per_sentence:  22.025
# complex_words_count:  356
# subjectivity_score:  0.13470319619326118
# word_count:  876
# avg_word_len:  4.588535754824064
# count_pronoun:  14
#
# URL_ID:  52
# URL:  https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/
# pos_score:  36.0
# neg_score:  0.0
# polarity_score:  0.999999972222223
# subjectivity_score:  0.1188118807960004
# average_sentence_length:  25.772727272727273
# percentage_of_complex_words:  0.26631393298059963
# fog_index:  10.415616482283149
# average_no_of_words_per_sentence:  25.772727272727273
# complex_words_count:  151
# subjectivity_score:  0.1188118807960004
# word_count:  303
# avg_word_len:  4.966490299823633
# count_pronoun:  0
#
# URL_ID:  53
# URL:  https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/
# pos_score:  99.0
# neg_score:  42.0
# polarity_score:  0.4042553162818772
# subjectivity_score:  0.19236016344834903
# average_sentence_length:  210.0
# percentage_of_complex_words:  0.18783068783068782
# fog_index:  84.07513227513228
# average_no_of_words_per_sentence:  210.0
# complex_words_count:  355
# subjectivity_score:  0.19236016344834903
# word_count:  733
# avg_word_len:  4.59047619047619
# count_pronoun:  17
# URL_ID:  54
# URL:  https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/
# pos_score:  36.0
# neg_score:  1.0
# polarity_score:  0.94594592037984
# subjectivity_score:  0.08545034622297841
# average_sentence_length:  18.88888888888889
# percentage_of_complex_words:  0.23647058823529413
# fog_index:  7.6501437908496746
# average_no_of_words_per_sentence:  18.88888888888889
# complex_words_count:  201
# subjectivity_score:  0.08545034622297841
# word_count:  433
# avg_word_len:  4.621176470588235
# count_pronoun:  0
#
# URL_ID:  55
# URL:  https://insights.blackcoffer.com/evolution-of-advertising-industry/
# pos_score:  26.0
# neg_score:  5.0
# polarity_score:  0.677419332986473
# subjectivity_score:  0.07013574644765669
# average_sentence_length:  20.175
# percentage_of_complex_words:  0.265179677819083
# fog_index:  8.176071871127634
# average_no_of_words_per_sentence:  20.175
# complex_words_count:  214
# subjectivity_score:  0.07013574644765669
# word_count:  442
# avg_word_len:  4.884758364312268
# count_pronoun:  1
#
# URL_ID:  56
# URL:  https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/
# pos_score:  0.0
# neg_score:  3.0
# polarity_score:  -0.9999996666667778
# subjectivity_score:  0.03124999967447917
# average_sentence_length:  29.428571428571427
# percentage_of_complex_words:  0.23786407766990292
# fog_index:  11.866574202496533
# average_no_of_words_per_sentence:  29.428571428571427
# complex_words_count:  49
# subjectivity_score:  0.03124999967447917
# word_count:  96
# avg_word_len:  4.839805825242719
# count_pronoun:  2
#
# URL_ID:  58
# URL:  https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/
# pos_score:  40.0
# neg_score:  85.0
# polarity_score:  -0.35999999712
# subjectivity_score:  0.1606683802562103
# average_sentence_length:  27.78181818181818
# percentage_of_complex_words:  0.20157068062827224
# fog_index:  11.193355544978582
# average_no_of_words_per_sentence:  27.78181818181818
# complex_words_count:  308
# subjectivity_score:  0.1606683802562103
# word_count:  778
# avg_word_len:  4.700261780104712
# count_pronoun:  2
#
# URL_ID:  59
# URL:  https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/
# pos_score:  19.0
# neg_score:  16.0
# polarity_score:  0.0857142832653062
# subjectivity_score:  0.09020618533452014
# average_sentence_length:  27.79310344827586
# percentage_of_complex_words:  0.19727047146401985
# fog_index:  11.196149567895953
# average_no_of_words_per_sentence:  27.79310344827586
# complex_words_count:  159
# subjectivity_score:  0.09020618533452014
# word_count:  388
# avg_word_len:  4.5657568238213395
# count_pronoun:  4
#
# URL_ID:  60
# URL:  https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/
# pos_score:  95.0
# neg_score:  42.0
# polarity_score:  0.386861311044808
# subjectivity_score:  0.14241164226360536
# average_sentence_length:  19.445454545454545
# percentage_of_complex_words:  0.17297802711547453
# fog_index:  7.847373029028008
# average_no_of_words_per_sentence:  19.445454545454545
# complex_words_count:  370
# subjectivity_score:  0.14241164226360536
# word_count:  962
# avg_word_len:  4.419354838709677
# count_pronoun:  15
#
# URL_ID:  61
# URL:  https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/
# pos_score:  46.0
# neg_score:  3.0
# polarity_score:  0.8775510024989592
# subjectivity_score:  0.12596400995896143
# average_sentence_length:  16.886363636363637
# percentage_of_complex_words:  0.21399730820995963
# fog_index:  6.840144377829438
# average_no_of_words_per_sentence:  16.886363636363637
# complex_words_count:  159
# subjectivity_score:  0.12596400995896143
# word_count:  389
# avg_word_len:  4.63257065948856
# count_pronoun:  3
#
# URL_ID:  62
# URL:  https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/
# pos_score:  17.0
# neg_score:  0.0
# polarity_score:  0.999999941176474
# subjectivity_score:  0.0783410134638663
# average_sentence_length:  24.647058823529413
# percentage_of_complex_words:  0.1718377088305489
# fog_index:  9.927558612943985
# average_no_of_words_per_sentence:  24.647058823529413
# complex_words_count:  72
# subjectivity_score:  0.0783410134638663
# word_count:  217
# avg_word_len:  4.58472553699284
# count_pronoun:  1
#
# URL_ID:  63
# URL:  https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/
# pos_score:  36.0
# neg_score:  12.0
# polarity_score:  0.4999999895833336
# subjectivity_score:  0.10643015497465598
# average_sentence_length:  26.02857142857143
# percentage_of_complex_words:  0.18660812294182216
# fog_index:  10.486071820605302
# average_no_of_words_per_sentence:  26.02857142857143
# complex_words_count:  170
# subjectivity_score:  0.10643015497465598
# word_count:  451
# avg_word_len:  4.374313940724479
# count_pronoun:  1
#
# URL_ID:  64
# URL:  https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/
# pos_score:  24.0
# neg_score:  8.0
# polarity_score:  0.49999998437500054
# subjectivity_score:  0.10774410738133297
# average_sentence_length:  28.31578947368421
# percentage_of_complex_words:  0.23048327137546468
# fog_index:  11.41850909802387
# average_no_of_words_per_sentence:  28.31578947368421
# complex_words_count:  124
# subjectivity_score:  0.10774410738133297
# word_count:  297
# avg_word_len:  4.724907063197026
# count_pronoun:  1
#
# URL_ID:  65
# URL:  https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/
# pos_score:  20.0
# neg_score:  10.0
# polarity_score:  0.33333332222222256
# subjectivity_score:  0.15873015789031664
# average_sentence_length:  15.5
# percentage_of_complex_words:  0.15898617511520738
# fog_index:  6.263594470046083
# average_no_of_words_per_sentence:  15.5
# complex_words_count:  69
# subjectivity_score:  0.15873015789031664
# word_count:  189
# avg_word_len:  4.65668202764977
# count_pronoun:  0
#
# URL_ID:  66
# URL:  https://insights.blackcoffer.com/how-we-forecast-future-technologies/
# pos_score:  6.0
# neg_score:  0.0
# polarity_score:  0.9999998333333611
# subjectivity_score:  0.06451612833853626
# average_sentence_length:  15.909090909090908
# percentage_of_complex_words:  0.2914285714285714
# fog_index:  6.480207792207792
# average_no_of_words_per_sentence:  15.909090909090908
# complex_words_count:  51
# subjectivity_score:  0.06451612833853626
# word_count:  93
# avg_word_len:  4.942857142857143
# count_pronoun:  3
#
# URL_ID:  67
# URL:  https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/
# pos_score:  49.0
# neg_score:  40.0
# polarity_score:  0.10112359436939782
# subjectivity_score:  0.20506912395145363
# average_sentence_length:  16.875
# percentage_of_complex_words:  0.14708994708994708
# fog_index:  6.808835978835979
# average_no_of_words_per_sentence:  16.875
# complex_words_count:  139
# subjectivity_score:  0.20506912395145363
# word_count:  434
# avg_word_len:  4.160846560846561
# count_pronoun:  30
#
# URL_ID:  68
# URL:  https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/
# pos_score:  13.0
# neg_score:  3.0
# polarity_score:  0.6249999609375024
# subjectivity_score:  0.16666666493055557
# average_sentence_length:  22.77777777777778
# percentage_of_complex_words:  0.16097560975609757
# fog_index:  9.17550135501355
# average_no_of_words_per_sentence:  22.77777777777778
# complex_words_count:  33
# subjectivity_score:  0.16666666493055557
# word_count:  96
# avg_word_len:  4.414634146341464
# count_pronoun:  1
#
# URL_ID:  69
# URL:  https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/
# pos_score:  52.0
# neg_score:  14.0
# polarity_score:  0.5757575670339763
# subjectivity_score:  0.15420560711634204
# average_sentence_length:  24.548387096774192
# percentage_of_complex_words:  0.2588699080157687
# fog_index:  9.922902801915985
# average_no_of_words_per_sentence:  24.548387096774192
# complex_words_count:  197
# subjectivity_score:  0.15420560711634204
# word_count:  428
# avg_word_len:  5.115637319316688
# count_pronoun:  0
#
# URL_ID:  70
# URL:  https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/
# pos_score:  4.0
# neg_score:  12.0
# polarity_score:  -0.4999999687500019
# subjectivity_score:  0.23188405461037603
# average_sentence_length:  28.166666666666668
# percentage_of_complex_words:  0.11834319526627218
# fog_index:  11.314003944773177
# average_no_of_words_per_sentence:  28.166666666666668
# complex_words_count:  20
# subjectivity_score:  0.23188405461037603
# word_count:  69
# avg_word_len:  4.3076923076923075
# count_pronoun:  5
# URL_ID:  71
# URL:  https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/
# pos_score:  10.0
# neg_score:  27.0
# polarity_score:  -0.4594594470416366
# subjectivity_score:  0.22981366316885923
# average_sentence_length:  18.90909090909091
# percentage_of_complex_words:  0.15144230769230768
# fog_index:  7.624213286713287
# average_no_of_words_per_sentence:  18.90909090909091
# complex_words_count:  63
# subjectivity_score:  0.22981366316885923
# word_count:  161
# avg_word_len:  4.336538461538462
# count_pronoun:  7
#
# URL_ID:  72
# URL:  https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/
# pos_score:  45.0
# neg_score:  49.0
# polarity_score:  -0.04255319103666818
# subjectivity_score:  0.0919765165440543
# average_sentence_length:  26.64864864864865
# percentage_of_complex_words:  0.23073022312373226
# fog_index:  10.751751548708953
# average_no_of_words_per_sentence:  26.64864864864865
# complex_words_count:  455
# subjectivity_score:  0.0919765165440543
# word_count:  1022
# avg_word_len:  4.78498985801217
# count_pronoun:  22
#
# URL_ID:  73
# URL:  https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/
# pos_score:  79.0
# neg_score:  30.0
# polarity_score:  0.4495412802794378
# subjectivity_score:  0.13164251191830614
# average_sentence_length:  27.55072463768116
# percentage_of_complex_words:  0.15412940557601262
# fog_index:  11.081941617302869
# average_no_of_words_per_sentence:  27.55072463768116
# complex_words_count:  293
# subjectivity_score:  0.13164251191830614
# word_count:  828
# avg_word_len:  4.4229352972119935
# count_pronoun:  21
#
# URL_ID:  74
# URL:  https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/
# pos_score:  49.0
# neg_score:  29.0
# polarity_score:  0.25641025312294546
# subjectivity_score:  0.0954712361132543
# average_sentence_length:  20.426829268292682
# percentage_of_complex_words:  0.16656716417910447
# fog_index:  8.237358572988715
# average_no_of_words_per_sentence:  20.426829268292682
# complex_words_count:  279
# subjectivity_score:  0.0954712361132543
# word_count:  817
# avg_word_len:  4.336716417910448
# count_pronoun:  33
#
# URL_ID:  75
# URL:  https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/
# pos_score:  42.0
# neg_score:  9.0
# polarity_score:  0.6470588108419841
# subjectivity_score:  0.13144329863030077
# average_sentence_length:  15.67741935483871
# percentage_of_complex_words:  0.147119341563786
# fog_index:  6.329815478560999
# average_no_of_words_per_sentence:  15.67741935483871
# complex_words_count:  143
# subjectivity_score:  0.13144329863030077
# word_count:  388
# avg_word_len:  4.106995884773663
# count_pronoun:  1
#
# URL_ID:  76
# URL:  https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/
# pos_score:  50.0
# neg_score:  10.0
# polarity_score:  0.6666666555555558
# subjectivity_score:  0.09188361394811086
# average_sentence_length:  24.5
# percentage_of_complex_words:  0.13481756338899195
# fog_index:  9.853927025355597
# average_no_of_words_per_sentence:  24.5
# complex_words_count:  218
# subjectivity_score:  0.09188361394811086
# word_count:  653
# avg_word_len:  4.08286951144094
# count_pronoun:  7
#
# URL_ID:  77
# URL:  https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/
# pos_score:  37.0
# neg_score:  6.0
# polarity_score:  0.7209302157923206
# subjectivity_score:  0.20574162580984867
# average_sentence_length:  32.9375
# percentage_of_complex_words:  0.1859582542694497
# fog_index:  13.24938330170778
# average_no_of_words_per_sentence:  32.9375
# complex_words_count:  98
# subjectivity_score:  0.20574162580984867
# word_count:  209
# avg_word_len:  4.250474383301707
# count_pronoun:  8
#
# URL_ID:  78
# URL:  https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/
# pos_score:  74.0
# neg_score:  20.0
# polarity_score:  0.5744680789950205
# subjectivity_score:  0.10621468914552012
# average_sentence_length:  25.985507246376812
# percentage_of_complex_words:  0.21751254880089235
# fog_index:  10.481207918071084
# average_no_of_words_per_sentence:  25.985507246376812
# complex_words_count:  390
# subjectivity_score:  0.10621468914552012
# word_count:  885
# avg_word_len:  4.669269380925822
# count_pronoun:  9
#
# URL_ID:  79
# URL:  https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/
# pos_score:  49.0
# neg_score:  79.0
# polarity_score:  -0.23437499816894533
# subjectivity_score:  0.2471042466272119
# average_sentence_length:  15.18421052631579
# percentage_of_complex_words:  0.15251299826689774
# fog_index:  6.134689409833076
# average_no_of_words_per_sentence:  15.18421052631579
# complex_words_count:  176
# subjectivity_score:  0.2471042466272119
# word_count:  518
# avg_word_len:  4.196707105719238
# count_pronoun:  13
#
# URL_ID:  80
# URL:  https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/
# pos_score:  63.0
# neg_score:  25.0
# polarity_score:  0.4318181769111571
# subjectivity_score:  0.1541155864201128
# average_sentence_length:  16.623376623376622
# percentage_of_complex_words:  0.13125
# fog_index:  6.70185064935065
# average_no_of_words_per_sentence:  16.623376623376622
# complex_words_count:  168
# subjectivity_score:  0.1541155864201128
# word_count:  571
# avg_word_len:  4.08203125
# count_pronoun:  5
#
# URL_ID:  81
# URL:  https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/
# pos_score:  62.0
# neg_score:  44.0
# polarity_score:  0.1698113191527234
# subjectivity_score:  0.18962432881999225
# average_sentence_length:  26.232558139534884
# percentage_of_complex_words:  0.14450354609929078
# fog_index:  10.55082467425367
# average_no_of_words_per_sentence:  26.232558139534884
# complex_words_count:  163
# subjectivity_score:  0.18962432881999225
# word_count:  559
# avg_word_len:  4.441489361702128
# count_pronoun:  0
#
# URL_ID:  82
# URL:  https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/
# pos_score:  48.0
# neg_score:  27.0
# polarity_score:  0.2799999962666667
# subjectivity_score:  0.11415525096780023
# average_sentence_length:  20.716666666666665
# percentage_of_complex_words:  0.2164119066773934
# fog_index:  8.373231429337624
# average_no_of_words_per_sentence:  20.716666666666665
# complex_words_count:  269
# subjectivity_score:  0.11415525096780023
# word_count:  657
# avg_word_len:  4.6838294448913915
# count_pronoun:  12
#
# URL_ID:  83
# URL:  https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/
# pos_score:  49.0
# neg_score:  83.0
# polarity_score:  -0.2575757556244261
# subjectivity_score:  0.24812030028548815
# average_sentence_length:  16.15068493150685
# percentage_of_complex_words:  0.15691263782866835
# fog_index:  6.523039027734207
# average_no_of_words_per_sentence:  16.15068493150685
# complex_words_count:  185
# subjectivity_score:  0.24812030028548815
# word_count:  532
# avg_word_len:  4.232400339270568
# count_pronoun:  15
#
# URL_ID:  84
# URL:  https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/
# pos_score:  30.0
# neg_score:  15.0
# polarity_score:  0.3333333259259261
# subjectivity_score:  0.13081395310809898
# average_sentence_length:  26.0
# percentage_of_complex_words:  0.1870026525198939
# fog_index:  10.474801061007959
# average_no_of_words_per_sentence:  26.0
# complex_words_count:  141
# subjectivity_score:  0.13081395310809898
# word_count:  344
# avg_word_len:  4.411140583554377
# count_pronoun:  8
#
# URL_ID:  85
# URL:  https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/
# pos_score:  14.0
# neg_score:  7.0
# polarity_score:  0.3333333174603182
# subjectivity_score:  0.13207547086744986
# average_sentence_length:  29.818181818181817
# percentage_of_complex_words:  0.1798780487804878
# fog_index:  11.999223946784923
# average_no_of_words_per_sentence:  29.818181818181817
# complex_words_count:  59
# subjectivity_score:  0.13207547086744986
# word_count:  159
# avg_word_len:  4.4939024390243905
# count_pronoun:  0
#
# URL_ID:  86
# URL:  https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/
# pos_score:  43.0
# neg_score:  21.0
# polarity_score:  0.3437499946289064
# subjectivity_score:  0.15023474143137386
# average_sentence_length:  34.208333333333336
# percentage_of_complex_words:  0.20828258221680876
# fog_index:  13.766646366220058
# average_no_of_words_per_sentence:  34.208333333333336
# complex_words_count:  171
# subjectivity_score:  0.15023474143137386
# word_count:  426
# avg_word_len:  4.833130328867235
# count_pronoun:  0
# URL_ID:  87
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/
# pos_score:  29.0
# neg_score:  51.0
# polarity_score:  -0.27499999656250007
# subjectivity_score:  0.11527377505003779
# average_sentence_length:  24.642857142857142
# percentage_of_complex_words:  0.19492753623188405
# fog_index:  9.935113871635611
# average_no_of_words_per_sentence:  24.642857142857142
# complex_words_count:  269
# subjectivity_score:  0.11527377505003779
# word_count:  694
# avg_word_len:  4.583333333333333
# count_pronoun:  7
#
# URL_ID:  88
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/
# pos_score:  113.0
# neg_score:  125.0
# polarity_score:  -0.050420167855377444
# subjectivity_score:  0.10818181813264463
# average_sentence_length:  20.384615384615383
# percentage_of_complex_words:  0.1552201257861635
# fog_index:  8.215934204160618
# average_no_of_words_per_sentence:  20.384615384615383
# complex_words_count:  617
# subjectivity_score:  0.10818181813264463
# word_count:  2200
# avg_word_len:  4.360251572327044
# count_pronoun:  0
#
# URL_ID:  89
# URL:  https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/
# pos_score:  66.0
# neg_score:  55.0
# polarity_score:  0.09090909015777611
# subjectivity_score:  0.13504464270642338
# average_sentence_length:  23.10843373493976
# percentage_of_complex_words:  0.20125130344108447
# fog_index:  9.323874015352336
# average_no_of_words_per_sentence:  23.10843373493976
# complex_words_count:  386
# subjectivity_score:  0.13504464270642338
# word_count:  896
# avg_word_len:  4.6068821689259645
# count_pronoun:  15
#
# URL_ID:  90
# URL:  https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/
# pos_score:  65.0
# neg_score:  66.0
# polarity_score:  -0.00763358772798788
# subjectivity_score:  0.1363163370069549
# average_sentence_length:  27.716666666666665
# percentage_of_complex_words:  0.24834636199639207
# fog_index:  11.186005211465224
# average_no_of_words_per_sentence:  27.716666666666665
# complex_words_count:  413
# subjectivity_score:  0.1363163370069549
# word_count:  961
# avg_word_len:  4.9957907396271795
# count_pronoun:  0
#
# URL_ID:  91
# URL:  https://insights.blackcoffer.com/human-rights-outlook/
# pos_score:  3.0
# neg_score:  1.0
# polarity_score:  0.49999987500003124
# subjectivity_score:  0.06060605968778698
# average_sentence_length:  23.142857142857142
# percentage_of_complex_words:  0.13580246913580246
# fog_index:  9.31146384479718
# average_no_of_words_per_sentence:  23.142857142857142
# complex_words_count:  22
# subjectivity_score:  0.06060605968778698
# word_count:  66
# avg_word_len:  4.160493827160494
# count_pronoun:  3
#
# URL_ID:  92
# URL:  https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/
# pos_score:  38.0
# neg_score:  6.0
# polarity_score:  0.7272727107438021
# subjectivity_score:  0.087999999824
# average_sentence_length:  25.564102564102566
# percentage_of_complex_words:  0.15245737211634905
# fog_index:  10.286623974487567
# average_no_of_words_per_sentence:  25.564102564102566
# complex_words_count:  152
# subjectivity_score:  0.087999999824
# word_count:  500
# avg_word_len:  4.311935807422267
# count_pronoun:  2
#
# URL_ID:  93
# URL:  https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/
# pos_score:  71.0
# neg_score:  42.0
# polarity_score:  0.2566371658704676
# subjectivity_score:  0.13294117631418687
# average_sentence_length:  16.833333333333332
# percentage_of_complex_words:  0.18564356435643564
# fog_index:  6.807590759075907
# average_no_of_words_per_sentence:  16.833333333333332
# complex_words_count:  375
# subjectivity_score:  0.13294117631418687
# word_count:  850
# avg_word_len:  4.508415841584158
# count_pronoun:  6
#
# URL_ID:  94
# URL:  https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/
# pos_score:  94.0
# neg_score:  18.0
# polarity_score:  0.6785714225127552
# subjectivity_score:  0.12017167369080292
# average_sentence_length:  21.032967032967033
# percentage_of_complex_words:  0.18495297805642633
# fog_index:  8.487168004409384
# average_no_of_words_per_sentence:  21.032967032967033
# complex_words_count:  354
# subjectivity_score:  0.12017167369080292
# word_count:  932
# avg_word_len:  4.466039707419018
# count_pronoun:  5
#
# URL_ID:  95
# URL:  https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/
# pos_score:  47.0
# neg_score:  37.0
# polarity_score:  0.1190476176303855
# subjectivity_score:  0.1448275859571938
# average_sentence_length:  25.782608695652176
# percentage_of_complex_words:  0.1821247892074199
# fog_index:  10.385893393943839
# average_no_of_words_per_sentence:  25.782608695652176
# complex_words_count:  216
# subjectivity_score:  0.1448275859571938
# word_count:  580
# avg_word_len:  4.566610455311973
# count_pronoun:  7
#
# URL_ID:  96
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/
# pos_score:  45.0
# neg_score:  67.0
# polarity_score:  -0.19642856967474492
# subjectivity_score:  0.11122144974059439
# average_sentence_length:  31.6
# percentage_of_complex_words:  0.22679324894514769
# fog_index:  12.73071729957806
# average_no_of_words_per_sentence:  31.6
# complex_words_count:  430
# subjectivity_score:  0.11122144974059439
# word_count:  1007
# avg_word_len:  4.848101265822785
# count_pronoun:  1
#
# URL_ID:  97
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/
# pos_score:  28.0
# neg_score:  50.0
# polarity_score:  -0.28205127843524
# subjectivity_score:  0.1439114388488719
# average_sentence_length:  22.354166666666668
# percentage_of_complex_words:  0.18080149114631874
# fog_index:  9.013987263125195
# average_no_of_words_per_sentence:  22.354166666666668
# complex_words_count:  194
# subjectivity_score:  0.1439114388488719
# word_count:  542
# avg_word_len:  4.589002795899348
# count_pronoun:  3
#
# URL_ID:  98
# URL:  https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/
# pos_score:  59.0
# neg_score:  57.0
# polarity_score:  0.01724137916171225
# subjectivity_score:  0.18800648267746112
# average_sentence_length:  18.45205479452055
# percentage_of_complex_words:  0.1789161098737936
# fog_index:  7.452388361757738
# average_no_of_words_per_sentence:  18.45205479452055
# complex_words_count:  241
# subjectivity_score:  0.18800648267746112
# word_count:  617
# avg_word_len:  4.423904974016333
# count_pronoun:  43
#
# URL_ID:  99
# URL:  https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/
# pos_score:  43.0
# neg_score:  33.0
# polarity_score:  0.13157894563711914
# subjectivity_score:  0.14757281524743143
# average_sentence_length:  31.675675675675677
# percentage_of_complex_words:  0.20477815699658702
# fog_index:  12.752181533068907
# average_no_of_words_per_sentence:  31.675675675675677
# complex_words_count:  240
# subjectivity_score:  0.14757281524743143
# word_count:  515
# avg_word_len:  4.722696245733788
# count_pronoun:  14
#
# URL_ID:  100
# URL:  https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/
# pos_score:  40.0
# neg_score:  56.0
# polarity_score:  -0.16666666493055557
# subjectivity_score:  0.12749003967132796
# average_sentence_length:  24.285714285714285
# percentage_of_complex_words:  0.20220588235294118
# fog_index:  9.795168067226891
# average_no_of_words_per_sentence:  24.285714285714285
# complex_words_count:  275
# subjectivity_score:  0.12749003967132796
# word_count:  753
# avg_word_len:  4.696323529411765
# count_pronoun:  3
#
# URL_ID:  101
# URL:  https://insights.blackcoffer.com/travel-and-tourism-outlook/
# pos_score:  3.0
# neg_score:  4.0
# polarity_score:  -0.1428571224489825
# subjectivity_score:  0.08235294020761247
# average_sentence_length:  20.9
# percentage_of_complex_words:  0.1291866028708134
# fog_index:  8.411674641148325
# average_no_of_words_per_sentence:  20.9
# complex_words_count:  27
# subjectivity_score:  0.08235294020761247
# word_count:  85
# avg_word_len:  4.1291866028708135
# count_pronoun:  3
#
# URL_ID:  102
# URL:  https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/
# pos_score:  44.0
# neg_score:  53.0
# polarity_score:  -0.09278350419810821
# subjectivity_score:  0.16412859532296345
# average_sentence_length:  20.5
# percentage_of_complex_words:  0.1772357723577236
# fog_index:  8.27089430894309
# average_no_of_words_per_sentence:  20.5
# complex_words_count:  218
# subjectivity_score:  0.16412859532296345
# word_count:  591
# avg_word_len:  4.386991869918699
# count_pronoun:  24
# URL_ID:  103
# URL:  https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/
# pos_score:  12.0
# neg_score:  30.0
# polarity_score:  -0.4285714183673472
# subjectivity_score:  0.10370370344764518
# average_sentence_length:  20.771428571428572
# percentage_of_complex_words:  0.1939477303988996
# fog_index:  8.38615052073099
# average_no_of_words_per_sentence:  20.771428571428572
# complex_words_count:  141
# subjectivity_score:  0.10370370344764518
# word_count:  405
# avg_word_len:  4.491059147180192
# count_pronoun:  7
#
# URL_ID:  104
# URL:  https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/
# pos_score:  41.0
# neg_score:  76.0
# polarity_score:  -0.29914529658850175
# subjectivity_score:  0.18810289358825902
# average_sentence_length:  24.28
# percentage_of_complex_words:  0.23393739703459637
# fog_index:  9.805574958813839
# average_no_of_words_per_sentence:  24.28
# complex_words_count:  284
# subjectivity_score:  0.18810289358825902
# word_count:  622
# avg_word_len:  4.939868204283361
# count_pronoun:  3
#
# URL_ID:  105
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/
# pos_score:  32.0
# neg_score:  44.0
# polarity_score:  -0.15789473476454297
# subjectivity_score:  0.14901960755094196
# average_sentence_length:  31.710526315789473
# percentage_of_complex_words:  0.15269709543568466
# fog_index:  12.745289364490063
# average_no_of_words_per_sentence:  31.710526315789473
# complex_words_count:  184
# subjectivity_score:  0.14901960755094196
# word_count:  510
# avg_word_len:  4.304564315352697
# count_pronoun:  13
#
# URL_ID:  106
# URL:  https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/
# pos_score:  1.0
# neg_score:  0.0
# polarity_score:  0.9999990000010001
# subjectivity_score:  0.009900990000980298
# average_sentence_length:  34.8
# percentage_of_complex_words:  0.1781609195402299
# fog_index:  13.991264367816093
# average_no_of_words_per_sentence:  34.8
# complex_words_count:  31
# subjectivity_score:  0.009900990000980298
# word_count:  101
# avg_word_len:  4.67816091954023
# count_pronoun:  0
#
# URL_ID:  107
# URL:  https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# pos_score:  23.0
# neg_score:  8.0
# polarity_score:  0.4838709521331951
# subjectivity_score:  0.10544217651210144
# average_sentence_length:  21.642857142857142
# percentage_of_complex_words:  0.15676567656765678
# fog_index:  8.719849127769919
# average_no_of_words_per_sentence:  21.642857142857142
# complex_words_count:  95
# subjectivity_score:  0.10544217651210144
# word_count:  294
# avg_word_len:  4.356435643564357
# count_pronoun:  3
#
# URL_ID:  108
# URL:  https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/
# pos_score:  46.0
# neg_score:  60.0
# polarity_score:  -0.1320754704521182
# subjectivity_score:  0.19887429606214954
# average_sentence_length:  33.516129032258064
# percentage_of_complex_words:  0.20211742059672763
# fog_index:  13.487298581141918
# average_no_of_words_per_sentence:  33.516129032258064
# complex_words_count:  210
# subjectivity_score:  0.19887429606214954
# word_count:  533
# avg_word_len:  4.728585178055823
# count_pronoun:  4
#
# URL_ID:  109
# URL:  https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis/
# pos_score:  29.0
# neg_score:  30.0
# polarity_score:  -0.016949152255099114
# subjectivity_score:  0.20136518702605738
# average_sentence_length:  26.7
# percentage_of_complex_words:  0.0986267166042447
# fog_index:  10.719450686641698
# average_no_of_words_per_sentence:  26.7
# complex_words_count:  79
# subjectivity_score:  0.20136518702605738
# word_count:  293
# avg_word_len:  3.902621722846442
# count_pronoun:  40
#
# URL_ID:  110
# URL:  https://insights.blackcoffer.com/covid-19-how-have-countries-been-responding/
# pos_score:  14.0
# neg_score:  62.0
# polarity_score:  -0.6315789390581719
# subjectivity_score:  0.13103448253269917
# average_sentence_length:  25.0
# percentage_of_complex_words:  0.19319148936170213
# fog_index:  10.077276595744681
# average_no_of_words_per_sentence:  25.0
# complex_words_count:  227
# subjectivity_score:  0.13103448253269917
# word_count:  580
# avg_word_len:  4.707234042553192
# count_pronoun:  0
#
# URL_ID:  111
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-2/
# pos_score:  25.0
# neg_score:  47.0
# polarity_score:  -0.30555555131172846
# subjectivity_score:  0.12631578925207756
# average_sentence_length:  22.115384615384617
# percentage_of_complex_words:  0.20521739130434782
# fog_index:  8.928240802675587
# average_no_of_words_per_sentence:  22.115384615384617
# complex_words_count:  236
# subjectivity_score:  0.12631578925207756
# word_count:  570
# avg_word_len:  4.82695652173913
# count_pronoun:  0
#
# URL_ID:  112
# URL:  https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-3/
# pos_score:  43.0
# neg_score:  61.0
# polarity_score:  -0.1730769214127219
# subjectivity_score:  0.1661341850381243
# average_sentence_length:  21.849056603773583
# percentage_of_complex_words:  0.20379965457685664
# fog_index:  8.821142503340175
# average_no_of_words_per_sentence:  21.849056603773583
# complex_words_count:  236
# subjectivity_score:  0.1661341850381243
# word_count:  626
# avg_word_len:  4.785837651122625
# count_pronoun:  2
#
# URL_ID:  113
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-3/
# pos_score:  30.0
# neg_score:  34.0
# polarity_score:  -0.062499999023437516
# subjectivity_score:  0.1549636800121945
# average_sentence_length:  26.08823529411765
# percentage_of_complex_words:  0.20067643742953778
# fog_index:  10.515564692618875
# average_no_of_words_per_sentence:  26.08823529411765
# complex_words_count:  178
# subjectivity_score:  0.1549636800121945
# word_count:  413
# avg_word_len:  4.617812852311161
# count_pronoun:  7
#
# URL_ID:  114
# URL:  https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work/
# pos_score:  84.0
# neg_score:  66.0
# polarity_score:  0.11999999920000001
# subjectivity_score:  0.18226002407987846
# average_sentence_length:  24.971014492753625
# percentage_of_complex_words:  0.17527568195008705
# fog_index:  10.058516069881485
# average_no_of_words_per_sentence:  24.971014492753625
# complex_words_count:  302
# subjectivity_score:  0.18226002407987846
# word_count:  823
# avg_word_len:  4.475914103308184
# count_pronoun:  4
#
# URL_ID:  115
# URL:  https://insights.blackcoffer.com/covid-19-how-have-countries-been-responding-2/
# pos_score:  53.0
# neg_score:  49.0
# polarity_score:  0.0392156858900423
# subjectivity_score:  0.11683848783867298
# average_sentence_length:  28.152542372881356
# percentage_of_complex_words:  0.20891029500301023
# fog_index:  11.344581067153747
# average_no_of_words_per_sentence:  28.152542372881356
# complex_words_count:  347
# subjectivity_score:  0.11683848783867298
# word_count:  873
# avg_word_len:  4.709211318482842
# count_pronoun:  2
#
# URL_ID:  116
# URL:  https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-4/
# pos_score:  28.0
# neg_score:  38.0
# polarity_score:  -0.15151514921946743
# subjectivity_score:  0.18032786835975992
# average_sentence_length:  83.18181818181819
# percentage_of_complex_words:  0.0994535519125683
# fog_index:  33.312508693492305
# average_no_of_words_per_sentence:  83.18181818181819
# complex_words_count:  91
# subjectivity_score:  0.18032786835975992
# word_count:  366
# avg_word_len:  4.139890710382514
# count_pronoun:  39
#
# URL_ID:  117
# URL:  https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-2/
# pos_score:  57.0
# neg_score:  90.0
# polarity_score:  -0.2244897943912259
# subjectivity_score:  0.1449704140582146
# average_sentence_length:  29.46969696969697
# percentage_of_complex_words:  0.19794344473007713
# fog_index:  11.86705616577082
# average_no_of_words_per_sentence:  29.46969696969697
# complex_words_count:  385
# subjectivity_score:  0.1449704140582146
# word_count:  1014
# avg_word_len:  4.743958868894602
# count_pronoun:  12
#
# URL_ID:  118
# URL:  https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-3/
# pos_score:  46.0
# neg_score:  66.0
# polarity_score:  -0.17857142697704084
# subjectivity_score:  0.18093699486116802
# average_sentence_length:  18.155844155844157
# percentage_of_complex_words:  0.11945636623748211
# fog_index:  7.3101202088326565
# average_no_of_words_per_sentence:  18.155844155844157
# complex_words_count:  167
# subjectivity_score:  0.18093699486116802
# word_count:  619
# avg_word_len:  4.130185979971388
# count_pronoun:  6
# URL_ID:  119
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-4/
# pos_score:  12.0
# neg_score:  16.0
# polarity_score:  -0.14285713775510223
# subjectivity_score:  0.13023255753380206
# average_sentence_length:  25.066666666666666
# percentage_of_complex_words:  0.23404255319148937
# fog_index:  10.120283687943264
# average_no_of_words_per_sentence:  25.066666666666666
# complex_words_count:  88
# subjectivity_score:  0.13023255753380206
# word_count:  215
# avg_word_len:  4.949468085106383
# count_pronoun:  1
#
# URL_ID:  120
# URL:  https://insights.blackcoffer.com/why-scams-like-nirav-modi-happen-with-indian-banks/
# pos_score:  87.0
# neg_score:  110.0
# polarity_score:  -0.11675126844288697
# subjectivity_score:  0.14969604851846804
# average_sentence_length:  27.136363636363637
# percentage_of_complex_words:  0.20979899497487436
# fog_index:  10.938465052535406
# average_no_of_words_per_sentence:  27.136363636363637
# complex_words_count:  501
# subjectivity_score:  0.14969604851846804
# word_count:  1316
# avg_word_len:  4.7868509212730315
# count_pronoun:  0
#
# URL_ID:  121
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-on-the-global-economy/
# pos_score:  53.0
# neg_score:  87.0
# polarity_score:  -0.242857141122449
# subjectivity_score:  0.21909233142552062
# average_sentence_length:  27.285714285714285
# percentage_of_complex_words:  0.1285631180919139
# fog_index:  10.96571096152248
# average_no_of_words_per_sentence:  27.285714285714285
# complex_words_count:  221
# subjectivity_score:  0.21909233142552062
# word_count:  639
# avg_word_len:  4.216404886561954
# count_pronoun:  32
#
# URL_ID:  122
# URL:  https://insights.blackcoffer.com/impact-of-covid-19coronavirus-on-the-indian-economy-2/
# pos_score:  52.0
# neg_score:  89.0
# polarity_score:  -0.26241134565665714
# subjectivity_score:  0.14857744979075085
# average_sentence_length:  22.941176470588236
# percentage_of_complex_words:  0.1753846153846154
# fog_index:  9.24662443438914
# average_no_of_words_per_sentence:  22.941176470588236
# complex_words_count:  342
# subjectivity_score:  0.14857744979075085
# word_count:  949
# avg_word_len:  4.469743589743589
# count_pronoun:  7
#
# URL_ID:  123
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-on-the-global-economy-2/
# pos_score:  71.0
# neg_score:  96.0
# polarity_score:  -0.14970059790598444
# subjectivity_score:  0.17560462652407505
# average_sentence_length:  26.8
# percentage_of_complex_words:  0.18009950248756218
# fog_index:  10.792039800995026
# average_no_of_words_per_sentence:  26.8
# complex_words_count:  362
# subjectivity_score:  0.17560462652407505
# word_count:  951
# avg_word_len:  4.599502487562189
# count_pronoun:  15
#
# URL_ID:  124
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy-3/
# pos_score:  34.0
# neg_score:  58.0
# polarity_score:  -0.2608695623818526
# subjectivity_score:  0.1597222219449267
# average_sentence_length:  23.367346938775512
# percentage_of_complex_words:  0.18165938864628822
# fog_index:  9.41960253096872
# average_no_of_words_per_sentence:  23.367346938775512
# complex_words_count:  208
# subjectivity_score:  0.1597222219449267
# word_count:  576
# avg_word_len:  4.437554585152839
# count_pronoun:  15
#
# URL_ID:  125
# URL:  https://insights.blackcoffer.com/should-celebrities-be-allowed-to-join-politics/
# pos_score:  85.0
# neg_score:  26.0
# polarity_score:  0.5315315267429592
# subjectivity_score:  0.10871694406589917
# average_sentence_length:  32.15625
# percentage_of_complex_words:  0.2118561710398445
# fog_index:  12.947242468415936
# average_no_of_words_per_sentence:  32.15625
# complex_words_count:  436
# subjectivity_score:  0.10871694406589917
# word_count:  1021
# avg_word_len:  4.701166180758017
# count_pronoun:  3
#
# URL_ID:  126
# URL:  https://insights.blackcoffer.com/how-prepared-is-india-to-tackle-a-possible-covid-19-outbreak/
# pos_score:  35.0
# neg_score:  30.0
# polarity_score:  0.07692307573964499
# subjectivity_score:  0.1356993734119011
# average_sentence_length:  28.939393939393938
# percentage_of_complex_words:  0.181151832460733
# fog_index:  11.648218308741868
# average_no_of_words_per_sentence:  28.939393939393938
# complex_words_count:  173
# subjectivity_score:  0.1356993734119011
# word_count:  479
# avg_word_len:  4.569633507853403
# count_pronoun:  4
#
# URL_ID:  127
# URL:  https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work/
# pos_score:  49.0
# neg_score:  99.0
# polarity_score:  -0.3378378355551498
# subjectivity_score:  0.19346405203468753
# average_sentence_length:  26.625
# percentage_of_complex_words:  0.20187793427230047
# fog_index:  10.73075117370892
# average_no_of_words_per_sentence:  26.625
# complex_words_count:  301
# subjectivity_score:  0.19346405203468753
# word_count:  765
# avg_word_len:  4.690140845070423
# count_pronoun:  6
#
# URL_ID:  128
# URL:  https://insights.blackcoffer.com/controversy-as-a-marketing-strategy/
# pos_score:  15.0
# neg_score:  18.0
# polarity_score:  -0.09090908815427007
# subjectivity_score:  0.20624999871093752
# average_sentence_length:  22.4
# percentage_of_complex_words:  0.2113095238095238
# fog_index:  9.04452380952381
# average_no_of_words_per_sentence:  22.4
# complex_words_count:  71
# subjectivity_score:  0.20624999871093752
# word_count:  160
# avg_word_len:  4.446428571428571
# count_pronoun:  5
#
# URL_ID:  129
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry/
# pos_score:  9.0
# neg_score:  8.0
# polarity_score:  0.05882352595155729
# subjectivity_score:  0.061594202675383326
# average_sentence_length:  25.428571428571427
# percentage_of_complex_words:  0.20786516853932585
# fog_index:  10.254574638844302
# average_no_of_words_per_sentence:  25.428571428571427
# complex_words_count:  111
# subjectivity_score:  0.061594202675383326
# word_count:  276
# avg_word_len:  4.758426966292135
# count_pronoun:  0
#
# URL_ID:  130
# URL:  https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets/
# pos_score:  50.0
# neg_score:  117.0
# polarity_score:  -0.4011976023880383
# subjectivity_score:  0.1716341210980122
# average_sentence_length:  38.285714285714285
# percentage_of_complex_words:  0.20149253731343283
# fog_index:  15.394882729211089
# average_no_of_words_per_sentence:  38.285714285714285
# complex_words_count:  378
# subjectivity_score:  0.1716341210980122
# word_count:  973
# avg_word_len:  4.735607675906183
# count_pronoun:  2
#
# URL_ID:  131
# URL:  https://insights.blackcoffer.com/what-are-the-key-policies-that-will-mitigate-the-impacts-of-covid-19-on-the-world-of-work/
# pos_score:  122.0
# neg_score:  36.0
# polarity_score:  0.5443037940233937
# subjectivity_score:  0.15177713722211608
# average_sentence_length:  26.802816901408452
# percentage_of_complex_words:  0.21807672096689437
# fog_index:  10.80835744895014
# average_no_of_words_per_sentence:  26.802816901408452
# complex_words_count:  415
# subjectivity_score:  0.15177713722211608
# word_count:  1041
# avg_word_len:  4.772464529689963
# count_pronoun:  0
#
# URL_ID:  132
# URL:  https://insights.blackcoffer.com/marketing-drives-results-with-a-focus-on-problems/
# pos_score:  50.0
# neg_score:  28.0
# polarity_score:  0.28205127843524
# subjectivity_score:  0.09737827703198718
# average_sentence_length:  26.76271186440678
# percentage_of_complex_words:  0.18366054464851173
# fog_index:  10.778548963622116
# average_no_of_words_per_sentence:  26.76271186440678
# complex_words_count:  290
# subjectivity_score:  0.09737827703198718
# word_count:  801
# avg_word_len:  4.636478784040532
# count_pronoun:  5
#
# URL_ID:  133
# URL:  https://insights.blackcoffer.com/continued-demand-for-sustainability/
# pos_score:  58.0
# neg_score:  27.0
# polarity_score:  0.3647058780622838
# subjectivity_score:  0.2019002370501182
# average_sentence_length:  27.77777777777778
# percentage_of_complex_words:  0.2906666666666667
# fog_index:  11.227377777777779
# average_no_of_words_per_sentence:  27.77777777777778
# complex_words_count:  218
# subjectivity_score:  0.2019002370501182
# word_count:  421
# avg_word_len:  5.217333333333333
# count_pronoun:  0
#
# URL_ID:  134
# URL:  https://insights.blackcoffer.com/coronavirus-disease-covid-19-effect-the-impact-and-role-of-mass-media-during-the-pandemic/
# pos_score:  16.0
# neg_score:  16.0
# polarity_score:  0.0
# subjectivity_score:  0.139737990656166
# average_sentence_length:  29.23076923076923
# percentage_of_complex_words:  0.21842105263157896
# fog_index:  11.779676113360324
# average_no_of_words_per_sentence:  29.23076923076923
# complex_words_count:  83
# subjectivity_score:  0.139737990656166
# word_count:  229
# avg_word_len:  4.734210526315789
# count_pronoun:  8
# URL_ID:  135
# URL:  https://insights.blackcoffer.com/should-people-wear-fabric-gloves-seeking-evidence-regarding-the-differential-transfer-of-covid-19-or-coronaviruses-generally-between-surfaces/
# pos_score:  8.0
# neg_score:  9.0
# polarity_score:  -0.05882352595155729
# subjectivity_score:  0.10119047558815193
# average_sentence_length:  23.9375
# percentage_of_complex_words:  0.12532637075718014
# fog_index:  9.625130548302872
# average_no_of_words_per_sentence:  23.9375
# complex_words_count:  48
# subjectivity_score:  0.10119047558815193
# word_count:  168
# avg_word_len:  4.164490861618799
# count_pronoun:  3
#
# URL_ID:  136
# URL:  https://insights.blackcoffer.com/why-is-there-a-severe-immunological-and-inflammatory-explosion-in-those-affected-by-sarms-covid-19/
# pos_score:  7.0
# neg_score:  20.0
# polarity_score:  -0.48148146364883465
# subjectivity_score:  0.13636363567493112
# average_sentence_length:  21.714285714285715
# percentage_of_complex_words:  0.18859649122807018
# fog_index:  8.761152882205513
# average_no_of_words_per_sentence:  21.714285714285715
# complex_words_count:  86
# subjectivity_score:  0.13636363567493112
# word_count:  198
# avg_word_len:  4.375
# count_pronoun:  3
#
# URL_ID:  137
# URL:  https://insights.blackcoffer.com/what-do-you-think-is-the-lesson-or-lessons-to-be-learned-with-covid-19/
# pos_score:  5.0
# neg_score:  10.0
# polarity_score:  -0.3333333111111126
# subjectivity_score:  0.1048951041615727
# average_sentence_length:  35.0
# percentage_of_complex_words:  0.15
# fog_index:  14.06
# average_no_of_words_per_sentence:  35.0
# complex_words_count:  42
# subjectivity_score:  0.1048951041615727
# word_count:  143
# avg_word_len:  4.242857142857143
# count_pronoun:  4
#
# URL_ID:  138
# URL:  https://insights.blackcoffer.com/coronavirus-the-unexpected-challenge-for-the-european-union/
# pos_score:  10.0
# neg_score:  15.0
# polarity_score:  -0.19999999200000032
# subjectivity_score:  0.1798561138139848
# average_sentence_length:  21.0
# percentage_of_complex_words:  0.21428571428571427
# fog_index:  8.485714285714286
# average_no_of_words_per_sentence:  21.0
# complex_words_count:  63
# subjectivity_score:  0.1798561138139848
# word_count:  139
# avg_word_len:  4.534013605442177
# count_pronoun:  7
#
# URL_ID:  139
# URL:  https://insights.blackcoffer.com/industrial-revolution-4-0-pros-and-cons/
# pos_score:  10.0
# neg_score:  3.0
# polarity_score:  0.5384614970414233
# subjectivity_score:  0.10156249920654298
# average_sentence_length:  27.857142857142858
# percentage_of_complex_words:  0.23076923076923078
# fog_index:  11.235164835164836
# average_no_of_words_per_sentence:  27.857142857142858
# complex_words_count:  45
# subjectivity_score:  0.10156249920654298
# word_count:  128
# avg_word_len:  4.471794871794872
# count_pronoun:  0
#
# URL_ID:  140
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy/
# pos_score:  16.0
# neg_score:  62.0
# polarity_score:  -0.5897435821827746
# subjectivity_score:  0.15324164999363132
# average_sentence_length:  27.05263157894737
# percentage_of_complex_words:  0.17607003891050585
# fog_index:  10.891480647143151
# average_no_of_words_per_sentence:  27.05263157894737
# complex_words_count:  181
# subjectivity_score:  0.15324164999363132
# word_count:  509
# avg_word_len:  4.613813229571984
# count_pronoun:  0
#
# URL_ID:  141
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy-2/
# pos_score:  13.0
# neg_score:  28.0
# polarity_score:  -0.3658536496133256
# subjectivity_score:  0.17982456061480456
# average_sentence_length:  35.13333333333333
# percentage_of_complex_words:  0.1555977229601518
# fog_index:  14.115572422517396
# average_no_of_words_per_sentence:  35.13333333333333
# complex_words_count:  82
# subjectivity_score:  0.17982456061480456
# word_count:  228
# avg_word_len:  4.364326375711575
# count_pronoun:  6
#
# URL_ID:  142
# URL:  https://insights.blackcoffer.com/impact-of-covid-19coronavirus-on-the-indian-economy/
# pos_score:  64.0
# neg_score:  81.0
# polarity_score:  -0.1172413785017836
# subjectivity_score:  0.14413518872352368
# average_sentence_length:  27.08108108108108
# percentage_of_complex_words:  0.19760479041916168
# fog_index:  10.911474348600098
# average_no_of_words_per_sentence:  27.08108108108108
# complex_words_count:  396
# subjectivity_score:  0.14413518872352368
# word_count:  1006
# avg_word_len:  4.709580838323354
# count_pronoun:  0
#
# URL_ID:  143
# URL:  https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-global-economy/
# pos_score:  27.0
# neg_score:  36.0
# polarity_score:  -0.1428571405895692
# subjectivity_score:  0.1909090903305785
# average_sentence_length:  19.61764705882353
# percentage_of_complex_words:  0.1904047976011994
# fog_index:  7.923220742569892
# average_no_of_words_per_sentence:  19.61764705882353
# complex_words_count:  127
# subjectivity_score:  0.1909090903305785
# word_count:  330
# avg_word_len:  4.727136431784108
# count_pronoun:  1
#
# URL_ID:  145
# URL:  https://insights.blackcoffer.com/blockchain-in-fintech/
# pos_score:  29.0
# neg_score:  14.0
# polarity_score:  0.3488372011898325
# subjectivity_score:  0.12181303081639368
# average_sentence_length:  23.87878787878788
# percentage_of_complex_words:  0.18527918781725888
# fog_index:  9.625626826642055
# average_no_of_words_per_sentence:  23.87878787878788
# complex_words_count:  146
# subjectivity_score:  0.12181303081639368
# word_count:  353
# avg_word_len:  4.840101522842639
# count_pronoun:  2
#
# URL_ID:  146
# URL:  https://insights.blackcoffer.com/blockchain-for-payments/
# pos_score:  46.0
# neg_score:  30.0
# polarity_score:  0.21052631301939062
# subjectivity_score:  0.1529175047225
# average_sentence_length:  20.479166666666668
# percentage_of_complex_words:  0.22075279755849442
# fog_index:  8.279967785690065
# average_no_of_words_per_sentence:  20.479166666666668
# complex_words_count:  217
# subjectivity_score:  0.1529175047225
# word_count:  497
# avg_word_len:  4.977619532044761
# count_pronoun:  3
#
# URL_ID:  147
# URL:  https://insights.blackcoffer.com/the-future-of-investing/
# pos_score:  52.0
# neg_score:  15.0
# polarity_score:  0.5522387977277792
# subjectivity_score:  0.10518053358684375
# average_sentence_length:  25.0
# percentage_of_complex_words:  0.2163265306122449
# fog_index:  10.0865306122449
# average_no_of_words_per_sentence:  25.0
# complex_words_count:  265
# subjectivity_score:  0.10518053358684375
# word_count:  637
# avg_word_len:  4.746122448979592
# count_pronoun:  2
#
# URL_ID:  148
# URL:  https://insights.blackcoffer.com/big-data-analytics-in-healthcare/
# pos_score:  52.0
# neg_score:  47.0
# polarity_score:  0.050505049994898486
# subjectivity_score:  0.1449487552782595
# average_sentence_length:  19.384615384615383
# percentage_of_complex_words:  0.23412698412698413
# fog_index:  7.847496947496947
# average_no_of_words_per_sentence:  19.384615384615383
# complex_words_count:  295
# subjectivity_score:  0.1449487552782595
# word_count:  683
# avg_word_len:  4.638888888888889
# count_pronoun:  2
#
# URL_ID:  149
# URL:  https://insights.blackcoffer.com/business-analytics-in-the-healthcare-industry/
# pos_score:  41.0
# neg_score:  3.0
# polarity_score:  0.863636344008265
# subjectivity_score:  0.13173652655168705
# average_sentence_length:  24.88
# percentage_of_complex_words:  0.27813504823151125
# fog_index:  10.063254019292605
# average_no_of_words_per_sentence:  24.88
# complex_words_count:  173
# subjectivity_score:  0.13173652655168705
# word_count:  334
# avg_word_len:  5.160771704180064
# count_pronoun:  0
#
# URL_ID:  150
# URL:  https://insights.blackcoffer.com/challenges-and-opportunities-of-big-data-in-healthcare/
# pos_score:  76.0
# neg_score:  42.0
# polarity_score:  0.288135590778512
# subjectivity_score:  0.20274914054510457
# average_sentence_length:  17.523076923076925
# percentage_of_complex_words:  0.2177348551360843
# fog_index:  7.096324711285203
# average_no_of_words_per_sentence:  17.523076923076925
# complex_words_count:  248
# subjectivity_score:  0.20274914054510457
# word_count:  582
# avg_word_len:  4.665496049165935
# count_pronoun:  9

# %%
final_results.head()
# Out:
#   URL_ID                                                URL  POSITIVE SCORE  \
# 0     37  https://insights.blackcoffer.com/ai-in-healthc...           102.0
# 1     38  https://insights.blackcoffer.com/what-if-the-c...            95.0
# 2     39  https://insights.blackcoffer.com/what-jobs-wil...            91.0
# 3     40  https://insights.blackcoffer.com/will-machine-...            90.0
# 4     41  https://insights.blackcoffer.com/will-ai-repla...            89.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            40.0        0.436620            0.122519            26.640000
# 1            49.0        0.319444            0.189225            20.487500
# 2            46.0        0.328467            0.135644            22.470588
# 3            35.0        0.440000            0.160875            19.293478
# 4            31.0        0.483333            0.125654            25.103896
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.261762  10.760705                         26.640000
# 1                     0.164735   8.260894                         20.487500
# 2                     0.251832   9.088968                         22.470588
# 3                     0.172958   7.786574                         19.293478
# 4                     0.193999  10.119158                         25.103896
#
#   COMPLEX WORD COUNT WORD COUNT  SYLLABLE COUNT PER WORD  AVG WORD LEN  \
# 0                523       1159                 1.874875      5.163163
# 1                270        761                 1.589384      4.293472
# 2                481       1010                 1.832461      4.896335
# 3                307        777                 1.645070      4.420282
# 4                375        955                 1.685463      4.578376
#
#   PRONOUN COUNT
# 0             4
# 1             8
# 2             3
# 3            22
# 4            20

# %%
final_results.to_csv('output.csv', index=False)
